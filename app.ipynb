# %% [markdown]
# # Open Jobs Analyzer and Recommendation

# %%
# for basic operations
import numpy as np
import pandas as pd

# for data visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# for interactivity
import ipywidgets as widgets
from ipywidgets import interact
from ipywidgets import interact_manual

# for interactive shells
from IPython.display import display

# seting for charts
plt.rcParams['figure.figsize'] = (15, 7)
plt.style.use('fivethirtyeight')

# %%
# lets import the dataset
jobs = pd.read_csv("jobs.csv")

# %%
# lets check the head of naukri
data = pd.read_csv('naukri.csv')

# %%
data['joblocation_adress'] = data['joblocation_address'].str.split(',')
  #pd.set_option('max_rows', 300000)
    #  data['joblocation_adress']

# %%
data = data.explode('joblocation_adress')
pd.set_option('max_rows', 30000)
#data['joblocation_adress'].value_counts()

# %%
data['joblocation_adress'] = data['joblocation_adress'].replace(('(Bengaluru/Bangalore)',' Bangalore',
                                                                ' Bangalore ','Bangalore ','Bengaluru/Bangalore ',
                                                                 ' Bengaluru/Bangalore ',' Bengaluru/Bangalore',
                                                                'Bengaluru/Bangalore','Bengaluru','NCR Bangalore',
                                                                'NCR Bangalore ','Near Bangalore', ' Bengaluru/Bangalore',
                                                                 ' Bengaluru/Bangalore ', ' Bengaluru',
                                                                 'Bangalore , Bangalore / Bangalore',
                                                                 'Bangalore , karnataka',' Bengaluru / Bangalore', 
                                                                 ' Bengaluru / Bangalore ', 'Bengaluru Bangalore',
                                                                 'India-Karnataka-Bangalore',' bangalore',' karnataka',
                                                                ' Bengaluru Bangalore'),
                                                                ('Bangalore','Bangalore','Bangalore','Bangalore','Bangalore',
                                                                'Bangalore','Bangalore','Bangalore','Bangalore','Bangalore',
                                                                'Bangalore','Bangalore','Bangalore','Bangalore','Bangalore',
                                                                 'Bangalore','Bangalore', 'Bangalore','Bangalore','Bangalore',
                                                                'Bangalore','Bangalore','Bangalore','Bangalore',))
                                                                
data['joblocation_adress'] = data['joblocation_adress'].replace(('Hyderabad / Secunderabad',' Hyderabad / Secunderabad',
                                                                 ' Hyderabad / Secunderabad ','Hyderabad / Secunderabad ',
                                                                ' Hyderabad','Hyderabad ',' Hyderabad ',
                                                                 'Hyderabad/Secunderabad','Hyderabad/Secunderabad ',
                                                                ' Hyderabad/Secunderabad ',' Hyderabad/Secunderabad',),
                                                                ('Hyderabad', 'Hyderabad','Hyderabad','Hyderabad',
                                                                 'Hyderabad', 'Hyderabad','Hyderabad','Hyderabad',
                                                                'Hyderabad','Hyderabad','Hyderabad'))


  
data['joblocation_adress'] = data['joblocation_adress'].replace(('NAVI MUMBAI',' NAVI MUMBAI','NAVI MUMBAI ',
                                                                 ' NAVI MUMBAI',' NAVI MUMBAI ','Mumbai , Mumbai',
                                                                 ' Mumbai',' Mumbai ','Mumbai ','mumbai','Navi Mumbai',
                                                                ' Navi Mumbai',' Navi Mumbai ','Navi Mumbai ', 
                                                                 ' Mumbai Suburbs','Mumbai Suburbs ','Mumbai Suburbs',
                                                                ' Mumbai Suburbs ','mumbai',' mumbai','mumbai ',
                                                                 ' maharashtra'),
                                                                ('Mumbai','Mumbai','Mumbai','Mumbai','Mumbai','Mumbai',
                                                                 'Mumbai','Mumbai','Mumbai', 'Mumbai','Mumbai','Mumbai',
                                                                'Mumbai','Mumbai','Mumbai','Mumbai','Mumbai','Mumbai','Mumbai',
                                                                'Mumbai','Mumbai', 'Mumbai'))

data['joblocation_adress'] = data['joblocation_adress'].replace(('Noida','Noida ',' Noida',' Delhi','Delhi','Delhi ',' Delhi ',
                                                                 'Gurgaon',' Gurgaon',' Gurgaon ','Gurgaon ', ' noida',
                                                                 ' Noida/Greater Noida',' Noida ', ' Delhi NCR',
                                                                 'Delhi/NCR(National Capital Region)',' Delhi/NCR ',
                                                                 ' Delhi/NCR(National Capital Region)',
                                                                 ' Delhi/NCR(National Capital Region) ',
                                                                 'Delhi/NCR(National Capital Region) ','Delhi , Delhi',
                                                                 'Noida , Noida/Greater Noida','Ghaziabad',
                                                                 'Delhi/NCR(National Capital Region) , Gurgaon',
                                                                 'NCR , NCR','NCR/NCR(National Capital Region)',
                                                                'NCR , NCR/Greater NCR','NCR/NCR(National Capital Region), NCR',
                                                                 'NCR , NCR/NCR(National Capital Region)',
                                                                 'NCR/NCR(National Capital Region)','NCR/Greater NCR',
                                                                 'NCR/NCR(National Capital Region) , NCR','Delhi/NCR ',
                                                                ' Noida/Greater Noida','Greater Noida',' Greater Noida',
                                                                 ' Greater Noida ','Greater Noida ','Ghaziabad',' Ghaziabad',
                                                                 'Ghaziabad ',' Ghaziabad ','Faridabad','Faridabad ',
                                                                 ' Faridabad',' Faridabad ',' Noida/Greater Noida',
                                                                 ' Noida/Greater Noida ',' delhi',' Delhi/NCR','Delhi NCR'
                                                                ),
                                                                ('NCR','NCR','NCR','NCR','NCR','NCR','NCR','NCR','NCR','NCR',
                                                                'NCR','NCR','NCR','NCR','NCR','NCR','NCR','NCR','NCR','NCR',
                                                                'NCR','NCR','NCR','NCR','NCR','NCR', 'NCR','NCR','NCR','NCR',
                                                                 'NCR','NCR','NCR','NCR','NCR','NCR','NCR','NCR','NCR','NCR',
                                                                 'NCR','NCR','NCR','NCR','NCR','NCR','NCR','NCR','NCR','NCR',
                                                                'NCR'))


data['joblocation_adress'] = data['joblocation_adress'].replace(('Chennai ',' Chennai',' Chennai ',' Chennai',
                                                                 'chennai ',' chennai',' chennai ',' chennai',),
                                                                ('Chennai', 'Chennai','Chennai','Chennai','Chennai',
                                                                'Chennai','Chennai','Chennai',))

data['joblocation_adress'] = data['joblocation_adress'].replace(('Pune ',' Pune',' Pune '),('Pune','Pune','Pune'))
data['joblocation_adress'] = data['joblocation_adress'].replace(('Kolkata ',' Kolkata',' Kolkata ',
                                                                ' kolkata','kolkata ',' kolkata'),
                                                                ('Kolkata','Kolkata','Kolkata',
                                                                  'Kolkata','Kolkata','Kolkata'))
data['joblocation_adress'] = data['joblocation_adress'].replace((' Ahmedabad','Ahmedabad ',' Ahmedabad '),('Ahmedabad',
                                                                                         'Ahmedabad','Ahmedabad'))
data['joblocation_adress'] = data['joblocation_adress'].replace(('Chandigarh ',' Chandigarh',' Chandigarh '),
                                                                ('Chandigarh','Chandigarh','Chandigarh'))
data['joblocation_adress'] = data['joblocation_adress'].replace(('Surat ',' Surat',' Surat '),
                                                                ('Surat','Surat','Surat'))
data['joblocation_adress'] = data['joblocation_adress'].replace(('Ernakulam / Kochi/ Cochin ', ' Kochi', 'Kochi ',' Kochi ',
                                                                 ' Cochin/ Kochi/ Ernakulam', ' Cochin/ Kochi/ Ernakulam ', 
                                                                 ' Ernakulam / Kochi/ Cochin',' Ernakulam / Kochi/ Cochin '),
                                                                ('Kochi','Kochi','Kochi','Kochi','Kochi','Kochi','Kochi',
                                                                 'Kochi',))
data['joblocation_adress'] = data['joblocation_adress'].replace(('Coimbatore ',' Coimbatore',' Coimbatore '),
                                                                ('Coimbatore','Coimbatore','Coimbatore'))
data['joblocation_adress'] = data['joblocation_adress'].replace(('Coimbatore ',' Coimbatore',' Coimbatore '),
                                                                ('Coimbatore','Coimbatore','Coimbatore'))
data['joblocation_adress'] = data['joblocation_adress'].replace(('Lucknow ',' Lucknow',' Lucknow '),
                                                                ('Lucknow','Lucknow','Lucknow'))
data['joblocation_adress'] = data['joblocation_adress'].replace(('Jaipur ',' Jaipur',' Jaipur ','jaipur ',' jaipur',
                                                                 ' jaipur '),
                                                                ('Jaipur','Jaipur','Jaipur','Jaipur','Jaipur','Jaipur'))
data['joblocation_adress'] = data['joblocation_adress'].replace(('Vijayawada ',' Vijayawada',' Vijayawada '),
                                                                ('Vijayawada','Vijayawada','Vijayawada'))
data['joblocation_adress'] = data['joblocation_adress'].replace(('Visakhapatnam ',' Visakhapatnam',' Visakhapatnam ',
                                                                'Visakhapatnam/Vizag ',' Visakhapatnam/Vizag',
                                                                 ' Visakhapatnam/Vizag '),
                                                                ('Visakhapatnam','Visakhapatnam','Visakhapatnam',
                                                                 'Visakhapatnam','Visakhapatnam','Visakhapatnam',
                                                                ))

data['joblocation_adress'] = data['joblocation_adress'].replace((' Bhubaneshwar',' Bhubaneshwar',' Bhubaneshwar '),
                                                                ('Bhubaneshwar','Bhubaneshwar','Bhubaneshwar'))
data['joblocation_adress'] = data['joblocation_adress'].replace((' Patna',' Patna',' Patna '),
                                                                ('Patna','Patna','Patna'))

data['joblocation_adress'] = data['joblocation_adress'].replace((' Trivandrum',' Trivandrum',' Trivandrum '),
                                                                ('Trivandrum','Trivandrum','Trivandrum'))

data['joblocation_adress'] = data['joblocation_adress'].replace((' Mangalore',' Mangalore',' Mangalore '),
                                                                ('Mangalore','Mangalore','Mangalore'))
data['joblocation_adress'] = data['joblocation_adress'].replace((' Indore',' Indore',' Indore '),
                                                                ('Indore','Indore','Indore'))
data['joblocation_adress'] = data['joblocation_adress'].replace((' Guwahati',' Guwahati',' Guwahati '),
                                                                ('Guwahati','Guwahati','Guwahati'))
data['joblocation_adress'] = data['joblocation_adress'].replace((' Nagpur',' Nagpur',' Nagpur '),
                                                                ('Nagpur','Nagpur','Nagpur'))
data['joblocation_adress'] = data['joblocation_adress'].replace((' Raipur',' Raipur',' Raipur '),
                                                                ('Raipur','Raipur','Raipur'))
data['joblocation_adress'] = data['joblocation_adress'].replace((' Thane',' Thane',' Thane '),
                                                                ('Thane','Thane','Thane'))
data['joblocation_adress'] = data['joblocation_adress'].replace((' Bhopal',' Bhopal',' Bhopal '),
                                                                ('Bhopal','Bhopal','Bhopal'))
data['joblocation_adress'] = data['joblocation_adress'].replace((' Vadodara/Baroda',' Vadodara/Baroda',' Vadodara/Baroda ',
                                                                ' Vadodara','Vadodara ',' Vadodara '),
                                                                ('Vadodara','Vadodara','Vadodara','Vadodara',
                                                                 'Vadodara','Vadodara',))
                                                                                                                                  
pd.set_option('max_rows', 2400)
#data['joblocation_adress'].value_counts()

# %%
counts = data['joblocation_adress'].value_counts()
data = data.loc[data['joblocation_adress'].isin(counts.index[counts > 25])]
#display(data['joblocation_adress'].value_counts())

#sns.countplot(data['joblocation_adress'], palette = 'inferno')
#plt.title('Locations with Highest Jobs', fontsize = 20)
#plt.xlabel(' ')
#plt.xticks(rotation = 90)
#plt.show()

# %%
pd.set_option('max_rows', 40000)
#data['experience'].str.split(' ')

# %%
data['experience'] = data['experience'].str.split(" ")
data['Min Experience'] = data['experience'].apply(lambda x: x[0])
data['Max Experience'] = data['experience'].apply(lambda x: x[2] if len(x) > 2 else x[1])

# %%
data['Min Experience'] = data['Min Experience'].replace('Not',0)
data['Max Experience'] = data['Max Experience'].replace(('Mentioned','-1'), (5,5))

# lets convert thenm into numerical data types
data['Min Experience'] = data['Min Experience'].astype('int')
data['Max Experience'] = data['Max Experience'].astype('int')

# %%
data['education'] = data['education'].fillna('UG: Any Graduate - Any Specialization')
#data['education'].isnull().sum()

# %%
data['Education'] = data['education'].str.split(' ')
data['Education'] = data['Education'].apply(lambda x: x[1] if len(x) > 1 else x[0])

#data['Education'].value_counts(dropna = False)

# %%
# let's do some cleaning

data['Education'] = data['Education'].replace(('B.Tech/B.E.','Graduation','Other','-','Not','B.Tech/B.E.,','Postgraduate',
                                               'PG:CA','Diploma,','B.Com,','B.Pharma,','B.A,','BCA,','B.Sc,','MBA/PGDM','B.B.A,',
                                              'PG:Other','Doctorate:Doctorate','Post'),
                                              ('B.Tech','B.Tech','B.Tech','B.Tech','B.Tech','B.Tech','B.Tech',
                                              'CA','Diploma','B.Com','B.Pharma','B.A','BCA','B.Sc','MBA','BBA',
                                              'B.Tech','Doctorate','B.Tech'))

#data['Education'].value_counts()

# %% [markdown]
# ## Vacancies for different education

# %%
counts = data['Education'].value_counts()
data = data.loc[data['Education'].isin(counts.index[counts >= 25])]
#display(data['Education'].value_counts())

plt.rcParams['figure.figsize'] = (12,6)
x = data[data['Education'] != 'Any']
sns.countplot(y = x['Education'], palette = 'inferno')
plt.title('', fontsize = 20)
plt.yticks(fontsize = 20)
plt.ylabel(" ")
plt.xlabel(" ")
plt.show()

# %% [markdown]
# ## Top sectors for jobs

# %%
data['industry'] = data['industry'].fillna(data['industry'].mode()[0])

#data['industry'].isnull().sum()

# %%
data['Industry'] = data['industry'].str.split(' / ')
data['Industry'] = data['Industry'].apply(lambda x: x[0])

#display(data['Industry'].value_counts())

plt.rcParams['figure.figsize'] = (15, 7)
plt.title('', fontsize = 20)
sns.barplot(y = data['Industry'].value_counts().head(10).index,
            x = data['Industry'].value_counts().head(10).values,
            palette = 'copper')
plt.show()

# %%
data['skills'] = data['skills'].fillna(data['skills'].mode()[0])
#data['skills'].isnull().sum()

# %%
data['Skills'] = data['skills'].str.split(" - ")
data['Skills'] = data['Skills'].apply(lambda x: x[1] if len(x) > 1 else x[0])
#display(data['Skills'].value_counts())

#plt.rcParams['figure.figsize'] = (15, 4)
#plt.title('Requirement of Overall Skills', fontsize = 20)
#data['Skills'].value_counts().head(25).plot(kind = 'bar', color = 'black')
#plt.grid()
#plt.yticks(fontsize = 15)
#plt.ylabel(" ")
#plt.xlabel(" ")
#plt.show()

# %%
# lets remove the columns which are not required

data = data.drop(['education',
                  'joblocation_address',
                  'experience',
                  'industry',
                  'skills',
                  'jobid',
                  'uniq_id',
                  'site_name'], axis = 1)

#data.columns

# %%
data['numberofpositions'] = data['numberofpositions'].fillna(1)
data['numberofpositions'] = data['numberofpositions'].astype('int')

# If the job post date and pay rate is missing it is useless, so lets remove the records where jobppostdate is not mentioned
data = data.dropna()
#data.isnull().sum().sum()

# %%
data['postdate'] = data['postdate'].str.split(" ")
data['postdate'] = data['postdate'].apply(lambda x: x[0])
#data['postdate'].head()

# %%
# By looking at the above result we can easily analyze that there are some duplicate

# lets print the no. of rows before removing Duplicates
#print("No. of Rows Before Removing Duplicates: ",data.shape[0])

# so lets remove all the duplicates from the data
data.drop_duplicates(subset = None, keep = 'first', inplace = True)

# lets print the no. of rows after removing Duplicates
#print("No. of Rows After Removing Duplicates: ",data.shape[0])

# %% [markdown]
# ## Searching for Jobs

# %%
pd.set_option('max_rows', 150)

@interact
def check(City = list(data['joblocation_adress'].value_counts().index),
          Industry = list(data['Industry'].value_counts().index),
          Experience = list(data['Min Experience'].value_counts().sort_values(ascending = False).index),
          Vacancies = 10
    
          ):
             return (data.loc[(data['numberofpositions'] > Vacancies)
                   & (data['joblocation_adress'] == City)
                   & (data['Industry'] == Industry)
                   & (data['Min Experience'] == Experience)][[
                                                      'company',
                                                      'jobtitle',
                                                      'Education',
                                                      'payrate',
                                                      'numberofpositions',
                                                      ]])
# Out:
#                                                  company  \
# 122                                            ITBMS Inc
# 343                        Confidential hiring for Subex
# 1424                      TQuanta Technologies Pvt. Ltd.
# 1668                                        Confidential
# 4005   ANTHROPLACE Consulting Pvt Ltd hiring for Fort...
# 4440                                      Career Network
# 4512             Intelizign Engineering Services Pvt Ltd
# 8652   Metro Career Solutions Pvt Ltd hiring for Many...
# 10078                                   Zing Consultants
# 11015                          ASAP Info Systems Pvt Ltd
# 12009                     Metro Career Solutions Pvt Ltd
# 14095  Brainsearch Consulting Pvt Ltd hiring for Fort...
# 20335                          ASAP Info Systems Pvt Ltd
# 20417                          ASAP Info Systems Pvt Ltd
# 20519       Teamware Solutions (quantum leap consulting)
# 21554                          ASAP Info Systems Pvt Ltd
#
#                                                 jobtitle Education  \
# 122    Mega Walk-in Drive - Tech M - Genesys - Pune /...       Any
# 343                                            JAVA Dvlp    B.Tech
# 1424                                      JAVA Developer    B.Tech
# 1668    Opening for Adobe CQ5 @ Bangalore / Pune /mumbai       Any
# 4005               Urgent Opening - Mainframe Operations       Any
# 4440   Pega PRPC Professionals!! Hyderabad, Bangalore...       Any
# 4512        Sr. C++ Software Developer in Cad/plm Domain    B.Tech
# 8652                                       BW Consultant       Any
# 10078  Immediate Openings - Java SE, .net, iOS & Andr...       Any
# 11015                                   Python Developer       Any
# 12009                                      BW Consultant       Any
# 14095  Build and Release on Java J2EE Application - I...       Any
# 20335                                  Cognos Developers       Any
# 20417                                      IOS Developer       Any
# 20519                     Service Desk_it Infrastructure       Any
# 21554                                           SAP ABAP       Any
#
#                                              payrate  numberofpositions
# 122                         5,00,000 - 12,00,000 P.A                 50
# 343                       Not Disclosed by Recruiter                 20
# 1424                      Not Disclosed by Recruiter                 18
# 1668                      Not Disclosed by Recruiter                 20
# 4005                            Best in the Industry                100
# 4440                      Not Disclosed by Recruiter                 18
# 4512                        5,00,000 - 12,00,000 P.A                 50
# 8652   4,00,000 - 8,00,000 P.A. INR Best In Industry                 25
# 10078                        2,50,000 - 6,00,000 P.A                 12
# 11015                     Not Disclosed by Recruiter                 20
# 12009  4,00,000 - 8,00,000 P.A. INR Best In Industry                 25
# 14095  8,00,000 - 15,00,000 P.A. Excellent Paymaster                 20
# 20335                     Not Disclosed by Recruiter                 12
# 20417                        2,25,000 - 6,50,000 P.A                 15
# 20519                     Not Disclosed by Recruiter                 29
# 21554                     Not Disclosed by Recruiter                 30

# %% [markdown]
# ## Search companies based on skiils

# %%
pd.set_option('max_rows', 500)
@interact
def check(
          
          skills = list(data['Skills'].value_counts().index),
          education = list(data['Education'].value_counts().index),
          vacancies =15
    
          ):
    return (data.loc[(data['Skills'] == skills)
          & (data['Education'] == education) 
          & (data['numberofpositions']>vacancies)
                   ][[
                                                      'company',
                                                      'jobtitle',
                                                      'Education',
                                                      'payrate',
                                                      'numberofpositions',
                                                      ]])
# Out:
#                                                  company  \
# 122                                            ITBMS Inc
# 122                                            ITBMS Inc
# 255          Take Wings hiring for http://takewing.co.in
# 255          Take Wings hiring for http://takewing.co.in
# 255          Take Wings hiring for http://takewing.co.in
# 367    Bull IT Services hiring for HCL Technology Lim...
# 420          Take Wings hiring for http://takewing.co.in
# 420          Take Wings hiring for http://takewing.co.in
# 420          Take Wings hiring for http://takewing.co.in
# 688    Techsist Solution Pvt Ltd hiring for HCL Techn...
# 688    Techsist Solution Pvt Ltd hiring for HCL Techn...
# 688    Techsist Solution Pvt Ltd hiring for HCL Techn...
# 688    Techsist Solution Pvt Ltd hiring for HCL Techn...
# 761          Take Wings hiring for http://takewing.co.in
# 761          Take Wings hiring for http://takewing.co.in
# 761          Take Wings hiring for http://takewing.co.in
# 825    Bull IT Services hiring for HCL Technology Lim...
# 877    Bull IT Services hiring for HCL Technology Lim...
# 887    Techsist Solution Pvt Ltd hiring for HCL Techn...
# 887    Techsist Solution Pvt Ltd hiring for HCL Techn...
# 887    Techsist Solution Pvt Ltd hiring for HCL Techn...
# 2574                                      Shell Infotech
# 3282                                  Truetech Solutions
# 3282                                  Truetech Solutions
# 3282                                  Truetech Solutions
# 3362                   Pentagon Global Solutions Limited
# 3362                   Pentagon Global Solutions Limited
# 3508                                  Truetech Solutions
# 3508                                  Truetech Solutions
# 3564                            Trigent Software Limited
# 3564                            Trigent Software Limited
# 3564                            Trigent Software Limited
# 3674                                           Kaay Labs
# 3771                          Ahsan Technologies Pvt Ltd
# 3782                                 HCL Corporation Ltd
# 3782                                 HCL Corporation Ltd
# 3782                                 HCL Corporation Ltd
# 3794           Merrill Technology Services india Pvt Ltd
# 3829                   Career Network hiring for Top MNC
# 3829                   Career Network hiring for Top MNC
# 3829                   Career Network hiring for Top MNC
# 3829                   Career Network hiring for Top MNC
# 3829                   Career Network hiring for Top MNC
# 3829                   Career Network hiring for Top MNC
# 3956             HCL Technologies Limited (TSS Division)
# 3956             HCL Technologies Limited (TSS Division)
# 3956             HCL Technologies Limited (TSS Division)
# 3956             HCL Technologies Limited (TSS Division)
# 3987         Take Wings hiring for http://takewing.co.in
# 3987         Take Wings hiring for http://takewing.co.in
# 3987         Take Wings hiring for http://takewing.co.in
# 4005   ANTHROPLACE Consulting Pvt Ltd hiring for Fort...
# 4005   ANTHROPLACE Consulting Pvt Ltd hiring for Fort...
# 4005   ANTHROPLACE Consulting Pvt Ltd hiring for Fort...
# 4029               Soft Trends Techno Solutions Pvt Ltd.
# 4227                                 HCL Corporation Ltd
# 4227                                 HCL Corporation Ltd
# 4227                                 HCL Corporation Ltd
# 4227                                 HCL Corporation Ltd
# 4424                                 HCL Corporation Ltd
# 4424                                 HCL Corporation Ltd
# 4424                                 HCL Corporation Ltd
# 4424                                 HCL Corporation Ltd
# 4440                                      Career Network
# 4440                                      Career Network
# 4440                                      Career Network
# 4510         Take Wings hiring for http://takewing.co.in
# 4510         Take Wings hiring for http://takewing.co.in
# 4510         Take Wings hiring for http://takewing.co.in
# 4531         Take Wings hiring for http://takewing.co.in
# 4531         Take Wings hiring for http://takewing.co.in
# 4531         Take Wings hiring for http://takewing.co.in
# 4612                                           Kaay Labs
# 4696   FINETURN SOLUTIONS AND SERVICES PVT LTD hiring...
# 4796                              Intellect Design Arena
# 4878          Headhuntersinc Consultancy Private Limited
# 4928             HCL Technologies Limited (TSS Division)
# 4928             HCL Technologies Limited (TSS Division)
# 4928             HCL Technologies Limited (TSS Division)
# 4928             HCL Technologies Limited (TSS Division)
# 5036                                  E-one Technologies
# 5036                                  E-one Technologies
# 5036                                  E-one Technologies
# 5036                                  E-one Technologies
# 5036                                  E-one Technologies
# 5036                                  E-one Technologies
# 5055                            HCL Technologies Limited
# 5057                          Ahsan Technologies Pvt Ltd
# 5059                               Indiajobs HR Solution
# 5142             Enlist Management Consultants Pvt. Ltd.
# 5226          Headhuntersinc Consultancy Private Limited
# 5249                            HCL Technologies Limited
# 5249                            HCL Technologies Limited
# 5249                            HCL Technologies Limited
# 7836   Metro Career Solutions Pvt Ltd hiring for Many...
# 7836   Metro Career Solutions Pvt Ltd hiring for Many...
# 7836   Metro Career Solutions Pvt Ltd hiring for Many...
# 7863              Out of Box hiring for Pegasus Infotech
# 7863              Out of Box hiring for Pegasus Infotech
# 7863              Out of Box hiring for Pegasus Infotech
# 7879   Metro Career Solutions Pvt Ltd hiring for Many...
# 7879   Metro Career Solutions Pvt Ltd hiring for Many...
# 7879   Metro Career Solutions Pvt Ltd hiring for Many...
# 7894   Metro Career Solutions Pvt Ltd hiring for Many...
# 7894   Metro Career Solutions Pvt Ltd hiring for Many...
# 7894   Metro Career Solutions Pvt Ltd hiring for Many...
# 7960   Metro Career Solutions Pvt Ltd hiring for Many...
# 7960   Metro Career Solutions Pvt Ltd hiring for Many...
# 7960   Metro Career Solutions Pvt Ltd hiring for Many...
# 8105         ESS CEE HR SOLUTIONS hiring for IT Industry
# 8115                        Eclinicalworks India Pvt Ltd
# 8336   Metro Career Solutions Pvt Ltd hiring for Many...
# 8336   Metro Career Solutions Pvt Ltd hiring for Many...
# 8336   Metro Career Solutions Pvt Ltd hiring for Many...
# 8338   Metro Career Solutions Pvt Ltd hiring for Many...
# 8338   Metro Career Solutions Pvt Ltd hiring for Many...
# 8338   Metro Career Solutions Pvt Ltd hiring for Many...
# 8429   Galaxy Consultants hiring for Urgently Hiring ...
# 8489                            Right Avenue Enterprises
# 8489                            Right Avenue Enterprises
# 8489                            Right Avenue Enterprises
# 8489                            Right Avenue Enterprises
# 8499   Metro Career Solutions Pvt Ltd hiring for Many...
# 8499   Metro Career Solutions Pvt Ltd hiring for Many...
# 8499   Metro Career Solutions Pvt Ltd hiring for Many...
# 8612    Randstad India Limited hiring for Randstad India
# 8652   Metro Career Solutions Pvt Ltd hiring for Many...
# 8652   Metro Career Solutions Pvt Ltd hiring for Many...
# 8652   Metro Career Solutions Pvt Ltd hiring for Many...
# 8919                   Pentagon Global Solutions Limited
# 8919                   Pentagon Global Solutions Limited
# 8919                   Pentagon Global Solutions Limited
# 9496   LanceSoft India Pvt. Ltd. hiring for US Recruiter
# 9719     Advanced Business and Healthcare Solution India
# 9741   Black and White Business Solutions Pvt Ltd hir...
# 10029                                     Career Network
# 10029                                     Career Network
# 10038                          ASAP Info Systems Pvt Ltd
# 10038                          ASAP Info Systems Pvt Ltd
# 10038                          ASAP Info Systems Pvt Ltd
# 10044                                     Shell Infotech
# 10117                               HCL Technologies Ltd
# 10202                                  MindGen Solutions
# 10202                                  MindGen Solutions
# 10213                                     Career Network
# 10213                                     Career Network
# 10213                                     Career Network
# 10213                                     Career Network
# 10213                                     Career Network
# 10213                                     Career Network
# 10413                                     Shell Infotech
# 10443                             CORALHIRE TECHNOLOGIES
# 10443                             CORALHIRE TECHNOLOGIES
# 10443                             CORALHIRE TECHNOLOGIES
# 10488                                     Shell Infotech
# 10504                               HCL Technologies Ltd
# 11015                          ASAP Info Systems Pvt Ltd
# 11015                          ASAP Info Systems Pvt Ltd
# 11015                          ASAP Info Systems Pvt Ltd
# 11142  Brainsearch Consulting Pvt Ltd hiring for Fort...
# 11142  Brainsearch Consulting Pvt Ltd hiring for Fort...
# 11142  Brainsearch Consulting Pvt Ltd hiring for Fort...
# 11266  Brainsearch Consulting Pvt Ltd hiring for Fort...
# 11266  Brainsearch Consulting Pvt Ltd hiring for Fort...
# 11266  Brainsearch Consulting Pvt Ltd hiring for Fort...
# 11327                     Volantis Technologies Pvt Ltd.
# 11834                                     Shell Infotech
# 12009                     Metro Career Solutions Pvt Ltd
# 12009                     Metro Career Solutions Pvt Ltd
# 12009                     Metro Career Solutions Pvt Ltd
# 13855                                     Campus Drivers
# 13855                                     Campus Drivers
# 13855                                     Campus Drivers
# 13855                                     Campus Drivers
# 13855                                     Campus Drivers
# 13855                                     Campus Drivers
# 14095  Brainsearch Consulting Pvt Ltd hiring for Fort...
# 14095  Brainsearch Consulting Pvt Ltd hiring for Fort...
# 14329                                          Yogam BPO
# 14439  Dev Solutions hiring for UK Client's Noida R&D...
# 15270                               CBSI India Pvt. Ltd.
# 15299                  Career Network hiring for Top MNC
# 15299                  Career Network hiring for Top MNC
# 15299                  Career Network hiring for Top MNC
# 15326  Global Hunt India Pvt. Ltd. hiring for Client ...
# 15376  Rivera Manpower hiring for Top MNC Companies i...
# 20394                                    Mphasis Limited
# 20484                                     Career Network
# 20484                                     Career Network
# 20484                                     Career Network
# 20484                                     Career Network
# 20484                                     Career Network
# 20484                                     Career Network
# 20546             Career Network hiring for US Based MNC
# 20546             Career Network hiring for US Based MNC
# 20546             Career Network hiring for US Based MNC
# 20701                  Career Network hiring for Top MNC
# 20701                  Career Network hiring for Top MNC
# 20701                  Career Network hiring for Top MNC
# 20701                  Career Network hiring for Top MNC
# 20701                  Career Network hiring for Top MNC
# 20701                  Career Network hiring for Top MNC
# 20786  Brainsearch Consulting Pvt Ltd hiring for Fort...
# 20786  Brainsearch Consulting Pvt Ltd hiring for Fort...
# 20786  Brainsearch Consulting Pvt Ltd hiring for Fort...
# 20851        Take Wings hiring for http://takewing.co.in
# 20851        Take Wings hiring for http://takewing.co.in
# 20851        Take Wings hiring for http://takewing.co.in
# 20889                  Career Network hiring for Top MNC
# 20889                  Career Network hiring for Top MNC
# 20889                  Career Network hiring for Top MNC
# 20910                 Orion Security Solutions Pvt. Ltd.
# 20910                 Orion Security Solutions Pvt. Ltd.
# 20910                 Orion Security Solutions Pvt. Ltd.
# 20910                 Orion Security Solutions Pvt. Ltd.
# 20910                 Orion Security Solutions Pvt. Ltd.
# 20910                 Orion Security Solutions Pvt. Ltd.
# 21007                                   Tourcop Services
# 21007                                   Tourcop Services
# 21007                                   Tourcop Services
# 21101             Career Network hiring for US Based MNC
# 21101             Career Network hiring for US Based MNC
# 21229                                      Aegis Limited
# 21247                                          Ace group
# 21247                                          Ace group
# 21247                                          Ace group
# 21247                                          Ace group
# 21273                   Yellow Box HR Services Pvt. Ltd.
# 21389                         UNIFY TECHNOLOGIES PVT LTD
# 21458        Take Wings hiring for http://takewing.co.in
# 21458        Take Wings hiring for http://takewing.co.in
# 21458        Take Wings hiring for http://takewing.co.in
# 21554                          ASAP Info Systems Pvt Ltd
# 21554                          ASAP Info Systems Pvt Ltd
# 21554                          ASAP Info Systems Pvt Ltd
# 21618                                          Ace group
# 21618                                          Ace group
# 21618                                          Ace group
# 21618                                          Ace group
# 21723        Boston Software Consultants India Pvt. Ltd.
# 21723        Boston Software Consultants India Pvt. Ltd.
#
#                                                 jobtitle Education  \
# 122    Mega Walk-in Drive - Tech M - Genesys - Pune /...       Any
# 122    Mega Walk-in Drive - Tech M - Genesys - Pune /...       Any
# 255                                    SAP SD Consultant       Any
# 255                                    SAP SD Consultant       Any
# 255                                    SAP SD Consultant       Any
# 367    Job Opening for HCL Technologies C++,linux/uni...       Any
# 420                             Junior Software Engineer       Any
# 420                             Junior Software Engineer       Any
# 420                             Junior Software Engineer       Any
# 688    Urgent Opening for L1 Voice Support (technical...       Any
# 688    Urgent Opening for L1 Voice Support (technical...       Any
# 688    Urgent Opening for L1 Voice Support (technical...       Any
# 688    Urgent Opening for L1 Voice Support (technical...       Any
# 761                            Web Developers - Freshers       Any
# 761                            Web Developers - Freshers       Any
# 761                            Web Developers - Freshers       Any
# 825    Job Opening for HCL Technologies C++,linux/uni...       Any
# 877    Job Opening for HCL Technologies C Programmer ...       Any
# 887       Urgent Opening for Escalation Engineer (voice)       Any
# 887       Urgent Opening for Escalation Engineer (voice)       Any
# 887       Urgent Opening for Escalation Engineer (voice)       Any
# 2574   PEGA Developer_exp:2-5 Years-bangalore-perm-sw...       Any
# 3282   Contract Job Opening for SAP ABAP OO( Object O...       Any
# 3282   Contract Job Opening for SAP ABAP OO( Object O...       Any
# 3282   Contract Job Opening for SAP ABAP OO( Object O...       Any
# 3362                 Opening for -database Administrator       Any
# 3362                 Opening for -database Administrator       Any
# 3508   Contract Job Opening for SAP ABAP Consultant B...       Any
# 3508   Contract Job Opening for SAP ABAP Consultant B...       Any
# 3564      Desktop Support - Bangalore/hyderabad/ Kolkata       Any
# 3564      Desktop Support - Bangalore/hyderabad/ Kolkata       Any
# 3564      Desktop Support - Bangalore/hyderabad/ Kolkata       Any
# 3674                                          Java, J2ee       Any
# 3771   F2f-interview CALL Letter FOR PHP Developer WI...       Any
# 3782   HCL TSS Hiring Fresher's for Leap, Job Opprtunity       Any
# 3782   HCL TSS Hiring Fresher's for Leap, Job Opprtunity       Any
# 3782   HCL TSS Hiring Fresher's for Leap, Job Opprtunity       Any
# 3794                 Sr. Systems Enginee/ Technical Lead       Any
# 3829             Pega PRPC Developers, Lead & Architects       Any
# 3829             Pega PRPC Developers, Lead & Architects       Any
# 3829             Pega PRPC Developers, Lead & Architects       Any
# 3829             Pega PRPC Developers, Lead & Architects       Any
# 3829             Pega PRPC Developers, Lead & Architects       Any
# 3829             Pega PRPC Developers, Lead & Architects       Any
# 3956   HCL Technologies Hiring Freshers!!! Walk-inter...       Any
# 3956   HCL Technologies Hiring Freshers!!! Walk-inter...       Any
# 3956   HCL Technologies Hiring Freshers!!! Walk-inter...       Any
# 3956   HCL Technologies Hiring Freshers!!! Walk-inter...       Any
# 3987                           Web Developers - Freshers       Any
# 3987                           Web Developers - Freshers       Any
# 3987                           Web Developers - Freshers       Any
# 4005               Urgent Opening - Mainframe Operations       Any
# 4005               Urgent Opening - Mainframe Operations       Any
# 4005               Urgent Opening - Mainframe Operations       Any
# 4029   IT Sales Manager/executive/general Manager/ter...       Any
# 4227      HCL - Walk-interview on 2nd Dec 2015 @ Chennai       Any
# 4227      HCL - Walk-interview on 2nd Dec 2015 @ Chennai       Any
# 4227      HCL - Walk-interview on 2nd Dec 2015 @ Chennai       Any
# 4227      HCL - Walk-interview on 2nd Dec 2015 @ Chennai       Any
# 4424   HCL Hiring Freshers!!! Walk-interview on 2nd D...       Any
# 4424   HCL Hiring Freshers!!! Walk-interview on 2nd D...       Any
# 4424   HCL Hiring Freshers!!! Walk-interview on 2nd D...       Any
# 4424   HCL Hiring Freshers!!! Walk-interview on 2nd D...       Any
# 4440   Pega PRPC Professionals!! Hyderabad, Bangalore...       Any
# 4440   Pega PRPC Professionals!! Hyderabad, Bangalore...       Any
# 4440   Pega PRPC Professionals!! Hyderabad, Bangalore...       Any
# 4510                            Junior Software Engineer       Any
# 4510                            Junior Software Engineer       Any
# 4510                            Junior Software Engineer       Any
# 4531                               Vb/asp/.net Developer       Any
# 4531                               Vb/asp/.net Developer       Any
# 4531                               Vb/asp/.net Developer       Any
# 4612                                               Unica       Any
# 4696   Very Urgent Openings for Software Engineers @ ...       Any
# 4796   Inviting Java Professional on 28th Nov'15 ( Sa...       Any
# 4878   PERL Developer @ UK Based MNC - Contact - Jai ...       Any
# 4928        HCL Freshers Walk-in on 25th Nov @ Hyderabad       Any
# 4928        HCL Freshers Walk-in on 25th Nov @ Hyderabad       Any
# 4928        HCL Freshers Walk-in on 25th Nov @ Hyderabad       Any
# 4928        HCL Freshers Walk-in on 25th Nov @ Hyderabad       Any
# 5036         Immediate Openings for Appian Professionals       Any
# 5036         Immediate Openings for Appian Professionals       Any
# 5036         Immediate Openings for Appian Professionals       Any
# 5036         Immediate Openings for Appian Professionals       Any
# 5036         Immediate Openings for Appian Professionals       Any
# 5036         Immediate Openings for Appian Professionals       Any
# 5055   HCL Hiring for Tool Profiles (HP OVO) @ Chenna...       Any
# 5057   F2f-interview CALL Letter FOR PHP Developer WI...       Any
# 5059   Urgent Requirement- Need L2, L3 Support Operat...       Any
# 5142   Delivery Support Executive for Logistics Indus...       Any
# 5226   Python Developer @ UK Based MNC - Contact - Ja...       Any
# 5249   HCL Walk-in for Fresher's on 25th Nov @ Hyderabad       Any
# 5249   HCL Walk-in for Fresher's on 25th Nov @ Hyderabad       Any
# 5249   HCL Walk-in for Fresher's on 25th Nov @ Hyderabad       Any
# 7836                                 Networking Engineer       Any
# 7836                                 Networking Engineer       Any
# 7836                                 Networking Engineer       Any
# 7863                   SAP Consultant ,SAP Professionals       Any
# 7863                   SAP Consultant ,SAP Professionals       Any
# 7863                   SAP Consultant ,SAP Professionals       Any
# 7879                        Junior Coordinator - Project       Any
# 7879                        Junior Coordinator - Project       Any
# 7879                        Junior Coordinator - Project       Any
# 7894                                SAP Bw/bi Consultant       Any
# 7894                                SAP Bw/bi Consultant       Any
# 7894                                SAP Bw/bi Consultant       Any
# 7960                         Junior System Administrator       Any
# 7960                         Junior System Administrator       Any
# 7960                         Junior System Administrator       Any
# 8105    Bulk Opening for PHP Developer_day Shift_it Firm       Any
# 8115           Java Developer ( Job Location: Ahmedabad)       Any
# 8336                               Junior .Net Developer       Any
# 8336                               Junior .Net Developer       Any
# 8336                               Junior .Net Developer       Any
# 8338                                    Junior Developer       Any
# 8338                                    Junior Developer       Any
# 8338                                    Junior Developer       Any
# 8429   Urgently Hiring FOR HCL Service DESK AND DATA ...       Any
# 8489                      Java ESB Integration Developer       Any
# 8489                      Java ESB Integration Developer       Any
# 8489                      Java ESB Integration Developer       Any
# 8489                      Java ESB Integration Developer       Any
# 8499                  Electronics Communication Engineer       Any
# 8499                  Electronics Communication Engineer       Any
# 8499                  Electronics Communication Engineer       Any
# 8612   Required MBA Freshers for Sales & Marketting M...       Any
# 8652                                       BW Consultant       Any
# 8652                                       BW Consultant       Any
# 8652                                       BW Consultant       Any
# 8919                   Junior Engineer Quality Assurance       Any
# 8919                   Junior Engineer Quality Assurance       Any
# 8919                   Junior Engineer Quality Assurance       Any
# 9496   Walkin for Freshers -US Recruiter-night Shift-...       Any
# 9719   .net Developer, Sr .net Developer, .net Tech L...       Any
# 9741           Excellent Opportunity for Project Manager       Any
# 10029  Immediate Openings for Calypso Professionals!!...       Any
# 10029  Immediate Openings for Calypso Professionals!!...       Any
# 10038  Urgent Requirement for java with web Technologies       Any
# 10038  Urgent Requirement for java with web Technologies       Any
# 10038  Urgent Requirement for java with web Technologies       Any
# 10044      Edi/evision Developer_exp:3-6 Years-bangalore       Any
# 10117  Urgent Openings_hcl Technologies_banglore_java...       Any
# 10202                                      AEM Architect       Any
# 10202                                      AEM Architect       Any
# 10213  Pega Professionals! Gurgaon,hyderabad, Bangalo...       Any
# 10213  Pega Professionals! Gurgaon,hyderabad, Bangalo...       Any
# 10213  Pega Professionals! Gurgaon,hyderabad, Bangalo...       Any
# 10213  Pega Professionals! Gurgaon,hyderabad, Bangalo...       Any
# 10213  Pega Professionals! Gurgaon,hyderabad, Bangalo...       Any
# 10213  Pega Professionals! Gurgaon,hyderabad, Bangalo...       Any
# 10413  Sitecore Developer-exp:3-8 Years-bangalore-per...       Any
# 10443                      Hiring for Automation Testers       Any
# 10443                      Hiring for Automation Testers       Any
# 10443                      Hiring for Automation Testers       Any
# 10488  Liferay Developer-exp:3-8 Years-bangalore-navy...       Any
# 10504  Urgent Openings_hcl Technologies_banglore_java...       Any
# 11015                                   Python Developer       Any
# 11015                                   Python Developer       Any
# 11015                                   Python Developer       Any
# 11142  Core Java (4 Yr - 9 Yr) - Bangalore / Delhi / ...       Any
# 11142  Core Java (4 Yr - 9 Yr) - Bangalore / Delhi / ...       Any
# 11142  Core Java (4 Yr - 9 Yr) - Bangalore / Delhi / ...       Any
# 11266  Core Java / Spring / Hibernate (lead / Archite...       Any
# 11266  Core Java / Spring / Hibernate (lead / Archite...       Any
# 11266  Core Java / Spring / Hibernate (lead / Archite...       Any
# 11327                            UI Developer_dt_sm_0008       Any
# 11834  Service Now Developers/ Implementation_exp:3-8...       Any
# 12009                                      BW Consultant       Any
# 12009                                      BW Consultant       Any
# 12009                                      BW Consultant       Any
# 13855                  Hiring Computer Graduates Fresher       Any
# 13855                  Hiring Computer Graduates Fresher       Any
# 13855                  Hiring Computer Graduates Fresher       Any
# 13855                  Hiring Computer Graduates Fresher       Any
# 13855                  Hiring Computer Graduates Fresher       Any
# 13855                  Hiring Computer Graduates Fresher       Any
# 14095  Build and Release on Java J2EE Application - I...       Any
# 14095  Build and Release on Java J2EE Application - I...       Any
# 14329  Medical Coding - Medical Transcription - Clini...       Any
# 14439  Angular JS with Mongo DB Developers Needed for...       Any
# 15270  Java Developer with Spring And Hibernate: 4-8 ...       Any
# 15299  Pega PRPC Openings !! Developers, Leads & Arch...       Any
# 15299  Pega PRPC Openings !! Developers, Leads & Arch...       Any
# 15299  Pega PRPC Openings !! Developers, Leads & Arch...       Any
# 15326                                Java/j2ee Developer       Any
# 15376  Hiring for Technical Support in Top IT / ITES ...       Any
# 20394  Mainframe & Java Consultants Drive in Hyderaba...       Any
# 20484  PEGA PRPC SE / SSE / Lead / Architect & Sr.arc...       Any
# 20484  PEGA PRPC SE / SSE / Lead / Architect & Sr.arc...       Any
# 20484  PEGA PRPC SE / SSE / Lead / Architect & Sr.arc...       Any
# 20484  PEGA PRPC SE / SSE / Lead / Architect & Sr.arc...       Any
# 20484  PEGA PRPC SE / SSE / Lead / Architect & Sr.arc...       Any
# 20484  PEGA PRPC SE / SSE / Lead / Architect & Sr.arc...       Any
# 20546  Pega H1B Holders with CSA, CSSA /LSA Certified...       Any
# 20546  Pega H1B Holders with CSA, CSSA /LSA Certified...       Any
# 20546  Pega H1B Holders with CSA, CSSA /LSA Certified...       Any
# 20701            Pega PRPC Developers, Lead & Architects       Any
# 20701            Pega PRPC Developers, Lead & Architects       Any
# 20701            Pega PRPC Developers, Lead & Architects       Any
# 20701            Pega PRPC Developers, Lead & Architects       Any
# 20701            Pega PRPC Developers, Lead & Architects       Any
# 20701            Pega PRPC Developers, Lead & Architects       Any
# 20786  Java Lead / SSE (spring / Struts / Hibernate) ...       Any
# 20786  Java Lead / SSE (spring / Struts / Hibernate) ...       Any
# 20786  Java Lead / SSE (spring / Struts / Hibernate) ...       Any
# 20851      IT - Freshers Java Developers 2015/2016 Batch       Any
# 20851      IT - Freshers Java Developers 2015/2016 Batch       Any
# 20851      IT - Freshers Java Developers 2015/2016 Batch       Any
# 20889  Openings for Pega PRPC Professionals!! Develop...       Any
# 20889  Openings for Pega PRPC Professionals!! Develop...       Any
# 20889  Openings for Pega PRPC Professionals!! Develop...       Any
# 20910                             Fire Engineers for UAE       Any
# 20910                             Fire Engineers for UAE       Any
# 20910                             Fire Engineers for UAE       Any
# 20910                             Fire Engineers for UAE       Any
# 20910                             Fire Engineers for UAE       Any
# 20910                             Fire Engineers for UAE       Any
# 21007  Freelancer/part Time/home Based Job Opportunit...       Any
# 21007  Freelancer/part Time/home Based Job Opportunit...       Any
# 21007  Freelancer/part Time/home Based Job Opportunit...       Any
# 21101  Pega H1B Holders with CSA, CSSA /LSA Certified...       Any
# 21101  Pega H1B Holders with CSA, CSSA /LSA Certified...       Any
# 21229  Walk-in @ Pune on Saturday 7th January 2017 fo...       Any
# 21247  Software Testing walk in Interview 20 dec 2016...       Any
# 21247  Software Testing walk in Interview 20 dec 2016...       Any
# 21247  Software Testing walk in Interview 20 dec 2016...       Any
# 21247  Software Testing walk in Interview 20 dec 2016...       Any
# 21273  Hiring for Digital Marketing Adwords & Spam Sp...       Any
# 21389  Walk In Drive for UI Developers (1 - 3 Years) ...       Any
# 21458                           Junior Software Engineer       Any
# 21458                           Junior Software Engineer       Any
# 21458                           Junior Software Engineer       Any
# 21554                                           SAP ABAP       Any
# 21554                                           SAP ABAP       Any
# 21554                                           SAP ABAP       Any
# 21618  java Developer & Asp.net walk in 20 dec 2016 t...       Any
# 21618  java Developer & Asp.net walk in 20 dec 2016 t...       Any
# 21618  java Developer & Asp.net walk in 20 dec 2016 t...       Any
# 21618  java Developer & Asp.net walk in 20 dec 2016 t...       Any
# 21723                               Openings for Filenet       Any
# 21723                               Openings for Filenet       Any
#
#                                                  payrate  numberofpositions
# 122                             5,00,000 - 12,00,000 P.A                 50
# 122                             5,00,000 - 12,00,000 P.A                 50
# 255    Competitive salary based on merit and market s...                 20
# 255    Competitive salary based on merit and market s...                 20
# 255    Competitive salary based on merit and market s...                 20
# 367                           Not Disclosed by Recruiter                 19
# 420    Competitive salary based on merit and market s...                 20
# 420    Competitive salary based on merit and market s...                 20
# 420    Competitive salary based on merit and market s...                 20
# 688                              1,00,000 - 4,00,000 P.A                100
# 688                              1,00,000 - 4,00,000 P.A                100
# 688                              1,00,000 - 4,00,000 P.A                100
# 688                              1,00,000 - 4,00,000 P.A                100
# 761    Competitive salary based on merit and market s...                 20
# 761    Competitive salary based on merit and market s...                 20
# 761    Competitive salary based on merit and market s...                 20
# 825                           Not Disclosed by Recruiter                 18
# 877                           Not Disclosed by Recruiter                 22
# 887                              1,00,000 - 4,00,000 P.A                100
# 887                              1,00,000 - 4,00,000 P.A                100
# 887                              1,00,000 - 4,00,000 P.A                100
# 2574                            5,00,000 - 15,00,000 P.A                100
# 3282                             3,00,000 - 8,00,000 P.A                 20
# 3282                             3,00,000 - 8,00,000 P.A                 20
# 3282                             3,00,000 - 8,00,000 P.A                 20
# 3362                          Not Disclosed by Recruiter                 18
# 3362                          Not Disclosed by Recruiter                 18
# 3508                             3,00,000 - 8,00,000 P.A                 20
# 3508                             3,00,000 - 8,00,000 P.A                 20
# 3564                             1,75,000 - 2,25,000 P.A                 20
# 3564                             1,75,000 - 2,25,000 P.A                 20
# 3564                             1,75,000 - 2,25,000 P.A                 20
# 3674                             1,00,000 - 6,00,000 P.A                100
# 3771                          Not Disclosed by Recruiter                 19
# 3782                          Not Disclosed by Recruiter               1000
# 3782                          Not Disclosed by Recruiter               1000
# 3782                          Not Disclosed by Recruiter               1000
# 3794                             2,00,000 - 7,00,000 P.A                 30
# 3829                          Not Disclosed by Recruiter                 60
# 3829                          Not Disclosed by Recruiter                 60
# 3829                          Not Disclosed by Recruiter                 60
# 3829                          Not Disclosed by Recruiter                 60
# 3829                          Not Disclosed by Recruiter                 60
# 3829                          Not Disclosed by Recruiter                 60
# 3956                             2,00,000 - 2,50,000 P.A                400
# 3956                             2,00,000 - 2,50,000 P.A                400
# 3956                             2,00,000 - 2,50,000 P.A                400
# 3956                             2,00,000 - 2,50,000 P.A                400
# 3987   Competitive salary based on merit and market s...                 20
# 3987   Competitive salary based on merit and market s...                 20
# 3987   Competitive salary based on merit and market s...                 20
# 4005                                Best in the Industry                100
# 4005                                Best in the Industry                100
# 4005                                Best in the Industry                100
# 4029                          Not Disclosed by Recruiter                 20
# 4227                             2,00,000 - 2,50,000 P.A                400
# 4227                             2,00,000 - 2,50,000 P.A                400
# 4227                             2,00,000 - 2,50,000 P.A                400
# 4227                             2,00,000 - 2,50,000 P.A                400
# 4424                             2,00,000 - 2,50,000 P.A                400
# 4424                             2,00,000 - 2,50,000 P.A                400
# 4424                             2,00,000 - 2,50,000 P.A                400
# 4424                             2,00,000 - 2,50,000 P.A                400
# 4440                          Not Disclosed by Recruiter                 18
# 4440                          Not Disclosed by Recruiter                 18
# 4440                          Not Disclosed by Recruiter                 18
# 4510   Competitive salary based on merit and market s...                 20
# 4510   Competitive salary based on merit and market s...                 20
# 4510   Competitive salary based on merit and market s...                 20
# 4531   Competitive salary based on merit and market s...                 20
# 4531   Competitive salary based on merit and market s...                 20
# 4531   Competitive salary based on merit and market s...                 20
# 4612                   50,00,000 - 50,00,000 & above P.A                 30
# 4696                          Not Disclosed by Recruiter                 20
# 4796                          Not Disclosed by Recruiter                 20
# 4878                             1,00,000 - 3,50,000 P.A                 25
# 4928                             2,00,000 - 2,50,000 P.A                400
# 4928                             2,00,000 - 2,50,000 P.A                400
# 4928                             2,00,000 - 2,50,000 P.A                400
# 4928                             2,00,000 - 2,50,000 P.A                400
# 5036                          Not Disclosed by Recruiter                 30
# 5036                          Not Disclosed by Recruiter                 30
# 5036                          Not Disclosed by Recruiter                 30
# 5036                          Not Disclosed by Recruiter                 30
# 5036                          Not Disclosed by Recruiter                 30
# 5036                          Not Disclosed by Recruiter                 30
# 5055                           As per Industry Standards                 20
# 5057                          Not Disclosed by Recruiter                 19
# 5059                          Not Disclosed by Recruiter                 20
# 5142                             1,25,000 - 1,50,000 P.A                 30
# 5226                             1,00,000 - 3,50,000 P.A                 25
# 5249                             2,00,000 - 2,50,000 P.A                400
# 5249                             2,00,000 - 2,50,000 P.A                400
# 5249                             2,00,000 - 2,50,000 P.A                400
# 7836       3,00,000 - 6,00,000 P.A. INR Best In Industry                 27
# 7836       3,00,000 - 6,00,000 P.A. INR Best In Industry                 27
# 7836       3,00,000 - 6,00,000 P.A. INR Best In Industry                 27
# 7863                             1,75,000 - 3,25,000 P.A                 20
# 7863                             1,75,000 - 3,25,000 P.A                 20
# 7863                             1,75,000 - 3,25,000 P.A                 20
# 7879       2,50,000 - 5,50,000 P.A. INR Best In Industry                 27
# 7879       2,50,000 - 5,50,000 P.A. INR Best In Industry                 27
# 7879       2,50,000 - 5,50,000 P.A. INR Best In Industry                 27
# 7894       3,00,000 - 7,00,000 P.A. INR Best In Industry                 34
# 7894       3,00,000 - 7,00,000 P.A. INR Best In Industry                 34
# 7894       3,00,000 - 7,00,000 P.A. INR Best In Industry                 34
# 7960       2,00,000 - 5,00,000 P.A. INR Best In Industry                 45
# 7960       2,00,000 - 5,00,000 P.A. INR Best In Industry                 45
# 7960       2,00,000 - 5,00,000 P.A. INR Best In Industry                 45
# 8105                             2,00,000 - 6,00,000 P.A                 20
# 8115                          Not Disclosed by Recruiter                100
# 8336       3,50,000 - 7,50,000 P.A. INR Best In Industry                 35
# 8336       3,50,000 - 7,50,000 P.A. INR Best In Industry                 35
# 8336       3,50,000 - 7,50,000 P.A. INR Best In Industry                 35
# 8338       4,00,000 - 8,00,000 P.A. INR Best In Industry                 22
# 8338       4,00,000 - 8,00,000 P.A. INR Best In Industry                 22
# 8338       4,00,000 - 8,00,000 P.A. INR Best In Industry                 22
# 8429            3,00,000 - 4,00,000 P.A. good incentives                 50
# 8489                            7,50,000 - 17,00,000 P.A                 20
# 8489                            7,50,000 - 17,00,000 P.A                 20
# 8489                            7,50,000 - 17,00,000 P.A                 20
# 8489                            7,50,000 - 17,00,000 P.A                 20
# 8499       2,00,000 - 7,00,000 P.A. INR Best in Industry                 43
# 8499       2,00,000 - 7,00,000 P.A. INR Best in Industry                 43
# 8499       2,00,000 - 7,00,000 P.A. INR Best in Industry                 43
# 8612                             1,25,000 - 2,00,000 P.A                 20
# 8652       4,00,000 - 8,00,000 P.A. INR Best In Industry                 25
# 8652       4,00,000 - 8,00,000 P.A. INR Best In Industry                 25
# 8652       4,00,000 - 8,00,000 P.A. INR Best In Industry                 25
# 8919       2,50,000 - 6,00,000 P.A. INR Best in Industry                 89
# 8919       2,50,000 - 6,00,000 P.A. INR Best in Industry                 89
# 8919       2,50,000 - 6,00,000 P.A. INR Best in Industry                 89
# 9496                                 As per the Industry                 30
# 9719                          Not Disclosed by Recruiter                 18
# 9741                          Not Disclosed by Recruiter                 20
# 10029                         Not Disclosed by Recruiter                 40
# 10029                         Not Disclosed by Recruiter                 40
# 10038                         Not Disclosed by Recruiter                 25
# 10038                         Not Disclosed by Recruiter                 25
# 10038                         Not Disclosed by Recruiter                 25
# 10044                           5,00,000 - 13,00,000 P.A                100
# 10117                         Not Disclosed by Recruiter                 20
# 10202                         Not Disclosed by Recruiter                 20
# 10202                         Not Disclosed by Recruiter                 20
# 10213                         Not Disclosed by Recruiter                 50
# 10213                         Not Disclosed by Recruiter                 50
# 10213                         Not Disclosed by Recruiter                 50
# 10213                         Not Disclosed by Recruiter                 50
# 10213                         Not Disclosed by Recruiter                 50
# 10213                         Not Disclosed by Recruiter                 50
# 10413                           5,50,000 - 15,50,000 P.A                100
# 10443  3,00,000 - 8,00,000 P.A. Not a Constrain for r...                 30
# 10443  3,00,000 - 8,00,000 P.A. Not a Constrain for r...                 30
# 10443  3,00,000 - 8,00,000 P.A. Not a Constrain for r...                 30
# 10488                           5,00,000 - 15,00,000 P.A                100
# 10504                         Not Disclosed by Recruiter                 20
# 11015                         Not Disclosed by Recruiter                 20
# 11015                         Not Disclosed by Recruiter                 20
# 11015                         Not Disclosed by Recruiter                 20
# 11142     10,00,000 - 20,00,000 P.A. Excellent Paymaster                 20
# 11142     10,00,000 - 20,00,000 P.A. Excellent Paymaster                 20
# 11142     10,00,000 - 20,00,000 P.A. Excellent Paymaster                 20
# 11266     12,00,000 - 22,00,000 P.A. Excellent Paymaster                 20
# 11266     12,00,000 - 22,00,000 P.A. Excellent Paymaster                 20
# 11266     12,00,000 - 22,00,000 P.A. Excellent Paymaster                 20
# 11327                         Not Disclosed by Recruiter                 50
# 11834                           7,00,000 - 17,00,000 P.A                100
# 12009      4,00,000 - 8,00,000 P.A. INR Best In Industry                 25
# 12009      4,00,000 - 8,00,000 P.A. INR Best In Industry                 25
# 12009      4,00,000 - 8,00,000 P.A. INR Best In Industry                 25
# 13855                            2,00,000 - 4,50,000 P.A                 20
# 13855                            2,00,000 - 4,50,000 P.A                 20
# 13855                            2,00,000 - 4,50,000 P.A                 20
# 13855                            2,00,000 - 4,50,000 P.A                 20
# 13855                            2,00,000 - 4,50,000 P.A                 20
# 13855                            2,00,000 - 4,50,000 P.A                 20
# 14095      8,00,000 - 15,00,000 P.A. Excellent Paymaster                 20
# 14095      8,00,000 - 15,00,000 P.A. Excellent Paymaster                 20
# 14329  2,00,000 - 3,00,000 P.A. PLUS Incentives, Week...               1200
# 14439                           6,00,000 - 16,00,000 P.A                 20
# 15270                         Not Disclosed by Recruiter                 20
# 15299                         Not Disclosed by Recruiter                 60
# 15299                         Not Disclosed by Recruiter                 60
# 15299                         Not Disclosed by Recruiter                 60
# 15326                           5,00,000 - 10,00,000 P.A                 25
# 15376  2,00,000 - 6,00,000 P.A. Salary hikes/incentiv...                100
# 20394                         Not Disclosed by Recruiter                 20
# 20484                         Not Disclosed by Recruiter                 80
# 20484                         Not Disclosed by Recruiter                 80
# 20484                         Not Disclosed by Recruiter                 80
# 20484                         Not Disclosed by Recruiter                 80
# 20484                         Not Disclosed by Recruiter                 80
# 20484                         Not Disclosed by Recruiter                 80
# 20546                         Not Disclosed by Recruiter                 70
# 20546                         Not Disclosed by Recruiter                 70
# 20546                         Not Disclosed by Recruiter                 70
# 20701                         Not Disclosed by Recruiter                 60
# 20701                         Not Disclosed by Recruiter                 60
# 20701                         Not Disclosed by Recruiter                 60
# 20701                         Not Disclosed by Recruiter                 60
# 20701                         Not Disclosed by Recruiter                 60
# 20701                         Not Disclosed by Recruiter                 60
# 20786     12,00,000 - 22,00,000 P.A. Excellent Paymaster                 20
# 20786     12,00,000 - 22,00,000 P.A. Excellent Paymaster                 20
# 20786     12,00,000 - 22,00,000 P.A. Excellent Paymaster                 20
# 20851  Competitive salary based on merit and market s...                 20
# 20851  Competitive salary based on merit and market s...                 20
# 20851  Competitive salary based on merit and market s...                 20
# 20889                         Not Disclosed by Recruiter                 60
# 20889                         Not Disclosed by Recruiter                 60
# 20889                         Not Disclosed by Recruiter                 60
# 20910                         Not Disclosed by Recruiter                200
# 20910                         Not Disclosed by Recruiter                200
# 20910                         Not Disclosed by Recruiter                200
# 20910                         Not Disclosed by Recruiter                200
# 20910                         Not Disclosed by Recruiter                200
# 20910                         Not Disclosed by Recruiter                200
# 21007           4,00,000 - 5,00,000 P.A. Good Incentives                300
# 21007           4,00,000 - 5,00,000 P.A. Good Incentives                300
# 21007           4,00,000 - 5,00,000 P.A. Good Incentives                300
# 21101                         Not Disclosed by Recruiter                 20
# 21101                         Not Disclosed by Recruiter                 20
# 21229                               Best in the Industry                 25
# 21247                            1,00,000 - 4,00,000 P.A                 20
# 21247                            1,00,000 - 4,00,000 P.A                 20
# 21247                            1,00,000 - 4,00,000 P.A                 20
# 21247                            1,00,000 - 4,00,000 P.A                 20
# 21273  2,25,000 - 2,50,000 P.A. Night Shift Allownace...                 50
# 21389                         Not Disclosed by Recruiter                 20
# 21458  Competitive salary based on merit and market s...                 20
# 21458  Competitive salary based on merit and market s...                 20
# 21458  Competitive salary based on merit and market s...                 20
# 21554                         Not Disclosed by Recruiter                 30
# 21554                         Not Disclosed by Recruiter                 30
# 21554                         Not Disclosed by Recruiter                 30
# 21618                            1,00,000 - 4,00,000 P.A                 20
# 21618                            1,00,000 - 4,00,000 P.A                 20
# 21618                            1,00,000 - 4,00,000 P.A                 20
# 21618                            1,00,000 - 4,00,000 P.A                 20
# 21723                           8,00,000 - 18,00,000 P.A                 20
# 21723                           8,00,000 - 18,00,000 P.A                 20

# %% [markdown]
# ## Industry recommendation

# %%
#lets create a matrix of skills vs jobtitle
#this matrix will be used for predicting the best suited job titles with respect to the skills
x = pd.crosstab(data['Education'],data['Industry'])
#x

# %%
@interact
def recommendation_jobs(Industry = list(data['Industry'].value_counts().index)):
    job = x[Industry]
    similar_jobs = x.corrwith(job)
    similar_jobs = similar_jobs.sort_values(ascending=False)
    similar_jobs = similar_jobs.iloc[2:]
    return similar_jobs.head(3)
# Out:
# Industry
# Internet          0.997958
# Telecom/ISP /     0.993423
# Semiconductors    0.993037
# dtype: float64
